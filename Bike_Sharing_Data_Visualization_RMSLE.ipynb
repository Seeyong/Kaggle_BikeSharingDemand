# %%
import pandas as pd

# %%
train = pd.read_csv('/Users/seeyonglee/Desktop/DataScience/Kaggle/Bike_Sharing_Demand/train.csv', parse_dates=['datetime'])

print(train.shape)
train.head()
# Out:
# (10886, 12)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train['year'] = train['datetime'].dt.year
train['month'] = train['datetime'].dt.month
train['day'] = train['datetime'].dt.day
train['hour'] = train['datetime'].dt.hour
train['minute'] = train['datetime'].dt.minute
train['second'] = train['datetime'].dt.second
train['dayofweek'] = train['datetime'].dt.dayofweek
train['year-month'] = train['year'].astype('str') + '-' + train['month'].astype('str')


print(train.shape)
train.head()
# Out:
# (10886, 20)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  dayofweek year-month
# ...

# %%
train['2011-1'] = train['year-month'] == '2011-1'
train['2011-2'] = train['year-month'] == '2011-2'
train['2011-3'] = train['year-month'] == '2011-3'
train['2011-4'] = train['year-month'] == '2011-4'
train['2011-5'] = train['year-month'] == '2011-5'
train['2011-6'] = train['year-month'] == '2011-6'
train['2011-7'] = train['year-month'] == '2011-7'
train['2011-8'] = train['year-month'] == '2011-8'
train['2011-9'] = train['year-month'] == '2011-9'
train['2011-10'] = train['year-month'] == '2011-10'
train['2011-11'] = train['year-month'] == '2011-11'
train['2011-12'] = train['year-month'] == '2011-12'
train['2012-1'] = train['year-month'] == '2012-1'
train['2012-2'] = train['year-month'] == '2012-2'
train['2012-3'] = train['year-month'] == '2012-3'
train['2012-4'] = train['year-month'] == '2012-4'
train['2012-5'] = train['year-month'] == '2012-5'
train['2012-6'] = train['year-month'] == '2012-6'
train['2012-7'] = train['year-month'] == '2012-7'
train['2012-8'] = train['year-month'] == '2012-8'
train['2012-9'] = train['year-month'] == '2012-9'
train['2012-10'] = train['year-month'] == '2012-10'
train['2012-11'] = train['year-month'] == '2012-11'
train['2012-12'] = train['year-month'] == '2012-12'

train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual   ...    2012-3  2012-4  2012-5  2012-6  \
# 0        81        0.0       3   ...     False   False   False   False
# 1        80        0.0       8   ...     False   False   False   False
# 2        80        0.0       5   ...     False   False   False   False
# 3        75        0.0       3   ...     False   False   False   False
# 4        75        0.0       0   ...     False   False   False   False
#
#    2012-7  2012-8  2012-9  2012-10  2012-11 2012-12
# ...

# %%
train['clear'] = train['weather'] == 1
train['mist'] = train['weather'] == 2
train['lightheavy'] = train['weather'] == 3
train['heavy'] = train['weather'] == 4

print(train.shape)
train.head()
# Out:
# (10886, 48)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  ...    2012-7  2012-8  2012-9  2012-10  \
# 0        81        0.0       3  ...     False   False   False    False
# 1        80        0.0       8  ...     False   False   False    False
# 2        80        0.0       5  ...     False   False   False    False
# 3        75        0.0       3  ...     False   False   False    False
# 4        75        0.0       0  ...     False   False   False    False
#
#    2012-11  2012-12  clear   mist  lightheavy  heavy
# ...

# %%
train['Spring'] = train['season'] == 1
train['Summer'] = train['season'] == 2
train['Autumn'] = train['season'] == 3
train['Winter'] = train['season'] == 4

print(train.shape)
train.head()
# Out:
# (10886, 52)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  ...    2012-11  2012-12  clear   mist  \
# 0        81        0.0       3  ...      False    False   True  False
# 1        80        0.0       8  ...      False    False   True  False
# 2        80        0.0       5  ...      False    False   True  False
# 3        75        0.0       3  ...      False    False   True  False
# 4        75        0.0       0  ...      False    False   True  False
#
#    lightheavy  heavy  Spring  Summer  Autumn Winter
# ...

# %%
train_zero_wind = train[train['windspeed'] == 0]

print(train_zero_wind.shape)
train_zero_wind.head()
# Out:
# (1313, 52)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  ...    2012-11  2012-12  clear   mist  \
# 0        81        0.0       3  ...      False    False   True  False
# 1        80        0.0       8  ...      False    False   True  False
# 2        80        0.0       5  ...      False    False   True  False
# 3        75        0.0       3  ...      False    False   True  False
# 4        75        0.0       0  ...      False    False   True  False
#
#    lightheavy  heavy  Spring  Summer  Autumn Winter
# ...

# %%
test = pd.read_csv('/Users/seeyonglee/Desktop/DataScience/Kaggle/Bike_Sharing_Demand/test.csv', parse_dates=['datetime'])

print(test.shape)
test.head()
# Out:
# (6493, 9)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
test['year'] = test['datetime'].dt.year
test['month'] = test['datetime'].dt.month
test['day'] = test['datetime'].dt.day
test['hour'] = test['datetime'].dt.hour
test['minute'] = test['datetime'].dt.minute
test['second'] = test['datetime'].dt.second
test['dayofweek'] = test['datetime'].dt.dayofweek
test['year-month'] = test['year'].astype('str') + '-' + test['year'].astype('str')

print(test.shape)
test.head()
# Out:
# (6493, 17)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  hour  minute  second  dayofweek  \
# 0        56    26.0027  2011      1   20     0       0       0          3
# 1        56     0.0000  2011      1   20     1       0       0          3
# 2        56     0.0000  2011      1   20     2       0       0          3
# 3        56    11.0014  2011      1   20     3       0       0          3
# 4        56    11.0014  2011      1   20     4       0       0          3
#
#   year-month
# 0  2011-2011
# 1  2011-2011
# ...

# %%
test['clear'] = test['weather'] == 1
test['mist'] = test['weather'] == 2
test['lightheavy'] = test['weather'] == 3
test['heavy'] = test['weather'] == 4

print(test.shape)
test.head()
# Out:
# (6493, 21)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  ...    day  hour  minute  second  dayofweek  \
# 0        56    26.0027  2011  ...     20     0       0       0          3
# 1        56     0.0000  2011  ...     20     1       0       0          3
# 2        56     0.0000  2011  ...     20     2       0       0          3
# 3        56    11.0014  2011  ...     20     3       0       0          3
# 4        56    11.0014  2011  ...     20     4       0       0          3
#
#    year-month clear   mist  lightheavy  heavy
# ...

# %%
test['Spring'] = test['season'] == 1
test['Summer'] = test['season'] == 2
test['Autumn'] = test['season'] == 3
test['Winter'] = test['season'] == 4

print(test.shape)
test.head()
# Out:
# (6493, 25)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year   ...    dayofweek  year-month  clear   mist  \
# 0        56    26.0027  2011   ...            3   2011-2011   True  False
# 1        56     0.0000  2011   ...            3   2011-2011   True  False
# 2        56     0.0000  2011   ...            3   2011-2011   True  False
# 3        56    11.0014  2011   ...            3   2011-2011   True  False
# 4        56    11.0014  2011   ...            3   2011-2011   True  False
#
#    lightheavy  heavy Spring  Summer  Autumn  Winter
# ...

# %%
test['2011-1'] = test['year-month'] == '2011-1'
test['2011-2'] = test['year-month'] == '2011-2'
test['2011-3'] = test['year-month'] == '2011-3'
test['2011-4'] = test['year-month'] == '2011-4'
test['2011-5'] = test['year-month'] == '2011-5'
test['2011-6'] = test['year-month'] == '2011-6'
test['2011-7'] = test['year-month'] == '2011-7'
test['2011-8'] = test['year-month'] == '2011-8'
test['2011-9'] = test['year-month'] == '2011-9'
test['2011-10'] = test['year-month'] == '2011-10'
test['2011-11'] = test['year-month'] == '2011-11'
test['2011-12'] = test['year-month'] == '2011-12'
test['2012-1'] = test['year-month'] == '2012-1'
test['2012-2'] = test['year-month'] == '2012-2'
test['2012-3'] = test['year-month'] == '2012-3'
test['2012-4'] = test['year-month'] == '2012-4'
test['2012-5'] = test['year-month'] == '2012-5'
test['2012-6'] = test['year-month'] == '2012-6'
test['2012-7'] = test['year-month'] == '2012-7'
test['2012-8'] = test['year-month'] == '2012-8'
test['2012-9'] = test['year-month'] == '2012-9'
test['2012-10'] = test['year-month'] == '2012-10'
test['2012-11'] = test['year-month'] == '2012-11'
test['2012-12'] = test['year-month'] == '2012-12'

test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year   ...     2012-3  2012-4  2012-5  2012-6  2012-7  \
# 0        56    26.0027  2011   ...      False   False   False   False   False
# 1        56     0.0000  2011   ...      False   False   False   False   False
# 2        56     0.0000  2011   ...      False   False   False   False   False
# 3        56    11.0014  2011   ...      False   False   False   False   False
# 4        56    11.0014  2011   ...      False   False   False   False   False
#
#    2012-8 2012-9  2012-10  2012-11  2012-12
# ...

# %%
test_zero_wind = test[test['windspeed'] == 0]
print(test_zero_wind.shape)
test_zero_wind.head()
# Out:
# (867, 49)
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 12 2011-01-20 12:00:00       1        0           1        2  12.30  16.665
# 60 2011-01-22 13:00:00       1        0           0        1   3.28   8.335
# 62 2011-01-22 15:00:00       1        0           0        1   4.92   7.575
#
#     humidity  windspeed  year   ...     2012-3  2012-4  2012-5  2012-6  \
# 1         56        0.0  2011   ...      False   False   False   False
# 2         56        0.0  2011   ...      False   False   False   False
# 12        42        0.0  2011   ...      False   False   False   False
# 60        35        0.0  2011   ...      False   False   False   False
# 62        28        0.0  2011   ...      False   False   False   False
#
#     2012-7  2012-8 2012-9  2012-10  2012-11  2012-12
# ...

# %% [markdown]
# ## Explore

# %%
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### datetime

# %%
import matplotlib.pyplot as plt

figure, ((ax1, ax2 ,ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18,9)

sns.barplot(data=train, x='year', y='count', ax=ax1)
sns.barplot(data=train, x='month', y='count', ax=ax2)
sns.barplot(data=train, x='day', y='count', ax=ax3)
sns.barplot(data=train, x='hour', y='count', ax=ax4)
sns.barplot(data=train, x='dayofweek', y='count', ax=ax5)

# %%
import matplotlib.pyplot as plt

figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(18,4)

sns.barplot(data=train, x='year', y='count', ax=ax1)
sns.barplot(data=train, x='month', y='count', ax=ax2)

figure, ax3 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,4)

sns.barplot(data=train, x='year-month', y='count', ax=ax3)

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,4)

sns.pointplot(data=train, x='hour', y='count', hue='workingday', ax=ax1)

figure, ax2 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,4)

sns.pointplot(data=train, x='hour', y='casual', hue='workingday', ax=ax2)

figure, ax3 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,4)

sns.pointplot(data=train, x='hour', y='registered', hue='workingday', ax=ax3)

figure, ax4 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,4)

sns.pointplot(data=train, x='hour', y='count', hue='dayofweek', ax=ax4)

# %% [markdown]
# ## Train

# %%
# year-month : one-hot-encoding
year_month_onehot = ['2011-1', '2011-2','2011-3','2011-4','2011-5','2011-6','2011-7','2011-8','2011-9','2011-10','2011-11','2011-12',
'2012-1','2012-2','2012-3','2012-4','2012-5','2012-6','2012-7','2012-8','2012-9','2012-10','2012-11','2012-12']

# %%
#for registered and count features
feature_names = ['season','weather','holiday','workingday','humidity','temp','year','hour','dayofweek','2011-1', '2011-2','2011-3','2011-4','2011-5','2011-6','2011-7','2011-8','2011-9','2011-10','2011-11','2011-12',
'2012-1','2012-2','2012-3','2012-4','2012-5','2012-6','2012-7','2012-8','2012-9','2012-10','2012-11','2012-12']

# %%
# for casual features
#feature_names = ['Spring','Summer','Autumn','Winter','weather','workingday','holiday','humidity','temp','year','hour','dayofweek']

# %%
X_train = train[feature_names]

print(X_train.shape)
X_train.head()
# Out:
# (10886, 33)
#    season  weather  holiday  workingday  humidity  temp  year  hour  \
# 0       1        1        0           0        81  9.84  2011     0
# 1       1        1        0           0        80  9.02  2011     1
# 2       1        1        0           0        80  9.02  2011     2
# 3       1        1        0           0        75  9.84  2011     3
# 4       1        1        0           0        75  9.84  2011     4
#
#    dayofweek  2011-1   ...     2012-3  2012-4  2012-5  2012-6  2012-7  2012-8  \
# 0          5    True   ...      False   False   False   False   False   False
# 1          5    True   ...      False   False   False   False   False   False
# 2          5    True   ...      False   False   False   False   False   False
# 3          5    True   ...      False   False   False   False   False   False
# 4          5    True   ...      False   False   False   False   False   False
#
#    2012-9  2012-10  2012-11  2012-12
# ...

# %%
X_test = test[feature_names]

print(X_test.shape)
X_test.head()
# Out:
# (6493, 33)
#    season  weather  holiday  workingday  humidity   temp  year  hour  \
# 0       1        1        0           1        56  10.66  2011     0
# 1       1        1        0           1        56  10.66  2011     1
# 2       1        1        0           1        56  10.66  2011     2
# 3       1        1        0           1        56  10.66  2011     3
# 4       1        1        0           1        56  10.66  2011     4
#
#    dayofweek  2011-1   ...     2012-3  2012-4  2012-5  2012-6  2012-7  2012-8  \
# 0          3   False   ...      False   False   False   False   False   False
# 1          3   False   ...      False   False   False   False   False   False
# 2          3   False   ...      False   False   False   False   False   False
# 3          3   False   ...      False   False   False   False   False   False
# 4          3   False   ...      False   False   False   False   False   False
#
#    2012-9  2012-10  2012-11  2012-12
# ...

# %%
label1_name = 'registered'
Y1_train = train[label1_name]

print(Y1_train.shape)
Y1_train.head()
# Out:
# (10886,)
# 0    13
# 1    32
# 2    27
# 3    10
# 4     1
# Name: registered, dtype: int64

# %%
import numpy as np

Y1_train = np.log(Y1_train + 1)

print(Y1_train.shape)
Y1_train.head()
# Out:
# (10886,)
# 0    2.639057
# 1    3.496508
# 2    3.332205
# 3    2.397895
# 4    0.693147
# Name: registered, dtype: float64

# %%
'''
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=4)
model
'''

from sklearn.ensemble import RandomForestRegressor

# n_estimators(default = 10)
# max_depth
# max_features

model = RandomForestRegressor(random_state=4,
                              n_estimators=300,
                              max_features=0.851358,
                              max_depth=83)
model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=83,
#            max_features=0.851358, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %% [markdown]
# ### Hold-out validation
# : **80%로 train -> 실제 20%와 predictions 20%를 비교해서 간격 좁히기**<br\>
# 간단한 대신에 정확도가 crose validation에 비해 정확도가 낮음
#
#
# ### cross validation
# : **A/B/C/D 각각 25% 그룹 3을 묶어서 교차로 나머지 25%를 예측 후 실제 DATA와 비교**<br\>
# 정확도가 높은 대신에 오래 걸림
# 보통 5 - 10개로 쪼갬

# %% [markdown]
# ## Score

# %% [markdown]
# Evaluation Metric = **Root Mean Squared Logarithmic Error**(RMSLE)
# $$ \sqrt{\frac{1}{n} \sum_{i=1}^n (\log(p_i+1)-\log(a_i+1))^2  } $$

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmsle(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)
    
    #log_predict = np.log(predict + 1)
    #log_actual = np.log(actual + 1)
    
    #difference = log_predict - log_actual
    difference = predict - actual
    difference = np.square(difference)
    
    mean_difference = difference.mean()
    
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
#registered
from sklearn.model_selection import cross_val_score

score = cross_val_score(model, X_train, Y1_train, cv=20, scoring=rmsle_scorer).mean()

print('Score = {0: 5f}'.format(score))
# Out:
# Score =  0.336179

# %%
model.fit(X_train, Y1_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=83,
#            max_features=0.851358, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
predictions1 = model.predict(X_test)

print(predictions1.shape)
predictions1[0:10]
# Out:
# (6493,)
# array([ 2.55567223,  1.69271273,  1.00779799,  1.00432409,  0.96645356,
#         1.80585305,  3.67897819,  4.64284934,  5.44339392,  4.83356784])

# %%
predictions1 = np.exp(predictions1) - 1

print(predictions1.shape)
# Out:
# (6493,)

# %%
label2_name = 'casual'
Y2_train = train[label2_name]

print(Y2_train.shape)
Y2_train.head()
# Out:
# (10886,)
# 0    3
# 1    8
# 2    5
# 3    3
# 4    0
# Name: casual, dtype: int64

# %%
Y2_train = np.log(Y2_train + 1)

print(Y2_train.shape)
Y2_train.head()
# Out:
# (10886,)
# 0    1.386294
# 1    2.197225
# 2    1.791759
# 3    1.386294
# 4    0.000000
# Name: casual, dtype: float64

# %%
#casual
from sklearn.model_selection import cross_val_score

score = cross_val_score(model, X_train, Y2_train, cv=20, scoring=rmsle_scorer).mean()

print('Score = {0: 5f}'.format(score))
# Out:
# Score =  0.552431

# %%
model.fit(X_train, Y2_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=83,
#            max_features=0.851358, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
predictions2 = model.predict(X_test)

print(predictions2.shape)
predictions1[0:10]
# Out:
# (6493,)
# array([  11.87995507,    4.43420224,    1.73956181,    1.73006138,
#           1.62860572,    5.08516019,   38.60590358,  102.83980144,
#         230.22561535,  124.658491  ])

# %%
predictions2 = np.exp(predictions2) - 1

# %%
submit = pd.read_csv('/Users/seeyonglee/Desktop/DataScience/Kaggle/Bike_Sharing_Demand/sampleSubmission.csv')

print(submit.shape)
submit.head()
# Out:
# (6493, 2)
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
submit['count'] = predictions1 + predictions2

print(submit.shape)
submit.head()
# Out:
# (6493, 2)
#               datetime      count
# 0  2011-01-20 00:00:00  13.112991
# 1  2011-01-20 01:00:00   4.881679
# 2  2011-01-20 02:00:00   2.599860
# 3  2011-01-20 03:00:00   2.233854
# 4  2011-01-20 04:00:00   1.827025

# %%
submit.to_csv('/Users/seeyonglee/Desktop/DataScience/Kaggle/Bike_Sharing_Demand/my_Submission.csv', index=False)
